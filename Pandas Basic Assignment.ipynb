# %% [markdown]
# Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as dp

# %%
data = (4, 8 , 15 , 16 , 23 , 42)
series = dp.Series(data)
print(series)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %% [markdown]
# Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the
# variable print it.

# %%
list_type = ["akshay" , 20 , 12.20 , "pwskills" , False , True , "data Science Master" , "pandas basic assignment" , 54 , 25.25]
variable = dp.Series(list_type)
print(variable)
# Out:
# 0                     akshay
# 1                         20
# 2                       12.2
# 3                   pwskills
# 4                      False
# 5                       True
# 6        data Science Master
# 7    pandas basic assignment
# 8                         54
# 9                      25.25
# dtype: object

# %% [markdown]
# Q3. Create a Pandas DataFrame that contains the following data:

# %%
data1 = {
    "name" :["alice" , "bob", "claire"],
    "age" :  [25 , 30 , 27],
    "gender" : ["female" , "male" , "female"]
}

# %%
df = dp.DataFrame(data1)
df
# Out:
#      name  age  gender
# 0   alice   25  female
# 1     bob   30    male
# 2  claire   27  female

# %%
print(df)
# Out:
#      name  age  gender
# 0   alice   25  female
# 1     bob   30    male
# 2  claire   27  female

# %% [markdown]
# Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.
#
# A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns, much like a spreadsheet. DataFrames are one of the most common data structures used in modern data analytics because they are a flexible and intuitive way of storing and working with data.
#
# As noted in the table, a Pandas Series is a 1D array of data, but a single-column DataFrame is a 2D table with one column. The main distinction between the two is this. For a single-column DataFrame, an index can be optional, but a Series has to have an index defined.1

# %%
lst = [1 ,23, 25 ,256]
df = dp.Series(lst)
df
# Out:
# 0      1
# 1     23
# 2     25
# 3    256
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
name = ['akshay' , 'kunal', 'john']
age = [21 , 22 , 22]
df5 = dp.DataFrame(age , index = name)
df5
# Out:
#          0
# akshay  21
# kunal   22
# john    22

# %% [markdown]
# Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can
# you give an example of when you might use one of these functions?

# %%
df02 = dp.read_excel("LUSID Excel - Setting up your market data.xlsx")
data = dp.DataFrame(df02)
data
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
data["unnamed:10"] =0

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
data.drop(columns = 'unnamed:10' )
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %% [markdown]
# Q6. Which of the following is mutable in nature Series, DataFrame, Panel?
#
# ans = Panel

# %% [markdown]
# Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
dataframe = {
    "name" :["alice" , "bob", "claire"],
    "age" :  [25 , 30 , 27],
    "gender" : ["female" , "male" , "female"],
    "location" : ["USA" , "india" , "Brazil"],
    "Marritial Status": ["married" , "single" , "Married"],
    "phone number" : [98465624 , 154156221 , 56546544],
    "qualification" : ["bcom", "data Analyst" , "data science"],
}

# %%
df10 = dp.DataFrame(dataframe)
df10
# Out:
#      name  age  gender location Marritial Status  phone number qualification
# 0   alice   25  female      USA          married      98465624          bcom
# 1     bob   30    male    india           single     154156221  data Analyst
# 2  claire   27  female   Brazil          Married      56546544  data science
